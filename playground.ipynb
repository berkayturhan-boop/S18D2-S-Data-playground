# %% [markdown]
# # Derin Öğrenmenin Temelleri -  Oyun Alanı

# %% [markdown]
# 🧠 Derin Öğrenme modülüne hoş geldiniz!
#
# 🎯 Bu görevde iki hedefimiz var:
# 1. Sinir ağlarının görsel bir temsilini elde etmek.
# 2. Sinir ağlarının ne yaptığını daha iyi anlamak.
#
# 👉 ***[Tensorflow Playground](https://playground.tensorflow.org/)*** kullanacağız.
#
# _(Bu ilk görev çok fazla kodlama gerektirmiyor_)

# %% [markdown]
# ## Derin Öğrenmede Sınıflandırma

# %% [markdown]
# ### (1) Veriler

# %% [markdown]
# ❓ [Oyun Alanı](https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=2& seed=0.23545&showTestData=false&discretize=false&percTrainData=70&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false& problem=classification&initZero=false&hideText=false&regularization_hide=true&showTestData_hide=false&stepButton_hide=false&activation_hide=false&problem_hide=false&batchSize_hide=true&dataset_hide=false&resetButton_hide=false&discretize_hide=false&playButton_hide=false& learningRate_hide=true&regularizationRate_hide=true&percTrainData_hide=false&numHiddenLayers_hide=false) ve aşağıdaki veri türünü seçin ❓
#
# - Bir sınıflandırma problemi
# - Daire veri kümesi (<span style="color:blue">mavi noktalar</span> içinde <span style="color:orange">turuncu noktalar</span>)
# - Eğitim ve test verilerinin oranı: $ 70 \% $
# - Gürültü yok ($ = 0$)
# - Test verilerini gösterme (sağ panel)
# - Çıktıyı ayrıştırma
# - Aktivasyon fonksiyonu: ***ReLU***
#
# <details>
#     <summary><i> Neden Relu? </i></summary>
#
# 💡 Genel olarak, varsayılan olarak deneyin. Birçok problem için daha iyi sonuç veriyor gibi görünüyor!
#
# _Not: Playground, **tüm** **gizli** katmanlar için kullanılan **tek** bir aktivasyon fonksiyonu seçmenize izin verir_
#
# </details>

# %% [markdown]
# ### (2) Özellikler

# %% [markdown]
# ❓ <u>Özelliklerle ilgili sorular</u> ❓
#
# 1. Yalnızca $X_1$ ve $X_2$ özelliklerini seçin (_gerekirse diğer özelliklerin seçimini kaldırın_).
# 2. $X_1^{2}$, $X_2^{2}$, $X_1 X_2$, $sin(X_1)$ ve $sin(X_2)$ gibi diğer değişkenleri kullanıyorsanız, bunlar hangi klasik Makine Öğrenimi işlemine karşılık gelir?

# %% [markdown]
# > Bu işlem Özellik Mühendisliği (Feature Engineering) olarak adlandırılır.

# %% [markdown]
# <details>
#     <summary><i>Cevap</i></summary>
#
# * Bunları dönüştürdüğünüz bir tür ***özellik mühendisliği*** ile ilgilidir.
#     * <i>Örnekler: çarpma, sinüs, karesi, ...</i>
# * Burada, bu alıştırmada ve yarın da, yalnızca ham girdi özellikleri $X_1$ ve $X_2$ kullanacağız.
# </details>

# %% [markdown]
# ### (3) ***Playground***'da Sinir Ağı Oluşturma ve Uyarlama

# %% [markdown]
# ❓ <u>Sinir Ağları Hakkında Sorular</u> ❓
#
# * 🧠 Aşağıdaki mimariye sahip bir model oluşturun:
# - üç gizli katman
# - ilk gizli katmanda 5 nöron
# - ikinci gizli katmanda 4 nöron
# - son gizli katmanda 3 nöron
# - ***Playground***'da çıktı katmanı gösterilmez:
#         - İkili sınıflandırma görevi için Playground, tanh (hiperbolik tanjant) fonksiyonu $ \large \phi(z) = \frac{sinh(z)}{cosh(z)} = \frac{e^z - e^{-z}}{e^z + e^{-z}} $ ile etkinleştirilen 1 nöronlu yoğun bir katman kullanır.
#         - Bu tanh fonksiyonu -1 ile 1 arasındaki değerleri çıkarır ve Playground'da güzel bir şekilde görselleştirilir.
# - Ancak, pratikte, ikili sınıflandırma için, 0 ile 1 arasındaki çıktıları olan sigmoid fonksiyonunu kullanmaya geri döneceğiz. Lojistik Regresyonu hatırlayın!
#         - Matematik severler için: sigmoid ve tanh aynı şekle sahiptir: birbirlerinin sadece kaydırılmış ve uzatılmış versiyonlarıdır.
#
# * 💪 ***Uyarlayın ve kayıp fonksiyonu stabilize olduğunda yinelemeleri durdurun.***
#
# * 👀 Dikkatlice gözlemleyin:
# - Tek tek nöronlara bakın ve her nöronun _.fit()_ sırasında neye uzmanlaştığını anlamaya çalışın.
# - Sonuçlarınızın genel şekli hakkında ne düşünüyorsunuz? Karşılaştırmak için farklı aktivasyon fonksiyonlarıyla sinir ağını yeniden çalıştırın. “Lineer” ile çalışmasını sağlayabilir misiniz?

# %% [markdown]
# <details>
#     <summary>Cevap: aktivasyon fonksiyonları hakkında bazı bilgiler</summary>
#
# - ReLu parça parça doğrusal olduğu için sonuçlar altıgen gibi görünebilir!
# - Doğrusal olarak ayrıştırılamayan bir problem, **Linear** gibi doğrusal bir aktivasyonla uyumlu hale getirilemez
# - Şaşırtıcı bir şekilde, **ReLu** (veya **LeakyReLu**) gibi parça parça doğrusal bir aktivasyon fonksiyonu, bu doğrusal olarak ayrıştırılamayan problemi iyi bir şekilde uyumlu hale getirir (her zaman doğru olmasa da)
# - `tanh` aktivasyonu, “daha yumuşak” bir karar sınırı sağlar
# - **Sigmoid** burada iyi çalışmıyor gibi görünüyor (yani, etkili bir şekilde sınıflandırma yapabilmesi için __çok__ fazla dönem gerekiyor)
#
# 🧑🏻‍🏫 Her zaman ReLu ile başlayın, bu güvenli bir seçimdir 🧑🏻‍🏫!
# </details>

# %% [markdown]
# Cevaplar:
# Nöronların Uzmanlaşması:
#
# İlk katmandaki nöronlar genellikle basit, düz çizgileri öğrenir.
# İkinci ve üçüncü katmana geçtikçe, bu çizgiler birleşerek daha karmaşık şekiller (köşeler, kavisler) oluşturur.
# Son katman ise bu parçaları birleştirip nihai "daire" şeklini ortaya çıkarır.
# Linear vs ReLU (Aktivasyon Fonksiyonu):
#
# Aktivasyon fonksiyonunu Linear yaptığımda, model problemi çözemedi. Daire şeklindeki veriyi düz bir çizgiyle ayırmaya çalıştı, bu da imkansızdı.
# ReLU kullandığımda ise model "doğrusal olmayan" (non-linear) sınırları öğrenebildi ve daire şeklini başarıyla çizdi.
# Sonuç: Karmaşık problemleri çözmek için katmanlara "bükülme" yeteneği veren ReLU gibi aktivasyon fonksiyonlarına ihtiyacımız vardır.

# %% [markdown]
# ### (4) ***Tensorflow.Keras***'da Sinir Ağı Oluşturma ve Uyarlama

# %% [markdown]
# 👇 Tensorflow'un Keras'ında sizin için aynı modeli yazdık - en azından mimariyi.

# %%
from keras import Sequential, Input, layers

model = Sequential()

model.add(Input(shape=(2,))) # 2 özellikli giriş katmanı

model.add(layers.Dense(5, activation='relu')) # 5 nöronlu 1. gizli katman
model.add(layers.Dense(4, activation='relu')) # 4 nöronlu 2. gizli katman
model.add(layers.Dense(3, activation='relu')) # 3 nöronlu 3. gizli katman

model.add(layers.Dense(1, activation='sigmoid')) # Ait olma olasılığını çıktı olarak veren çıktı katmanı
                                                 # “başarı” sınıfına

# %% [markdown]
# <details>
#   <summary><i>Bir Sinir Ağı (Neural Network) kodu hakkında neyi anlamalıyız?</i> 👆</summary>
#
# - <u>İlk Gizli Katman (a.k.a. ***Girdi Katmanı / Input Layer***)</u>:
#   - Sinir ağına giren her veri noktası iki özelliğe sahiptir:
#     \( X = \begin{bmatrix} X_{1} \\ X_{2} \end{bmatrix} \)
#   - Sinir ağına ***girdi özelliklerinin sayısını*** ***`input_dim` parametresi*** ile belirtmeniz gerekir.
#   - Bir sinir ağı insan beynini taklit etmeye çalışır. Burada, bu noktaları analiz etmeye başlamak için 5 nöron kullanmak istiyoruz.
#   - Her veri noktası, 5 nöronla oluşturulmuş ilk gizli katmandan geçer:
#     \( layer_1 = \begin{bmatrix} a_{1} \\ a_{2} \\ a_{3} \\ a_{4} \\ a_{5} \end{bmatrix} \)
#
# - <u>İkinci Gizli Katman</u>:
#   - Bilginin, 4 nöronlu ikinci bir gizli katmandan ***akmasını*** istersek ne olur? Bu tamamen mümkündür!
#   - İkinci katmandaki bu 4 nöron
#     \( layer_2 = \begin{bmatrix} b_{1} \\ b_{2} \\ b_{3} \\ b_{4} \end{bmatrix} \),
#     birinci katmandaki 5 nöronun çıktısını analiz eder.
#
# - <u>Üçüncü Gizli Katman</u>:
#   - Bilginin 3 nöronlu üçüncü bir gizli katmandan **akmaya devam etmesini** istersek? Bu da tamamen mümkündür!
#   - İkinci katmandaki her nöronun çıktısı, 3 nöronla oluşturulmuş üçüncü gizli katmandan geçer:
#     \( layer_3 = \begin{bmatrix} c_{1} \\ c_{2} \\ c_{3} \end{bmatrix} \)
#   - Bu 3 nöron, \( layer_2 \) içindeki nöronların çıktısını analiz eder.
#
# - <u>Tahmin (Predictive) Katmanı</u>:
#   - İkili (binary) bir sınıflandırma problemiyle uğraşıyorsunuz.
#   - Sınıf A veya B’ye ait olma olasılığını tahmin etmek için iki nöron kullanılabilir...
#   - Ancak “başarı” olasılığını tahmin eden tek bir nöron yeterlidir.
#
# - <u>Aktivasyon fonksiyonları hakkında</u>:
#   - Basitliğine rağmen ***ReLU***, katmanlara doğrusal olmayanlık (non-linearity) eklemek için oldukça etkilidir.
#   - Tahmin katmanı için, sınıflandırma problemlerinde kullanılacak en iyi aktivasyon fonksiyonu ***sigmoid*** fonksiyonudur.
#     Bu konu Decision Science ve Machine Learning bölümlerinde daha önce tartışılmıştı.
#
# - <u>Ağın Sequential (Sıralı) yapısı hakkında</u>:
#   - **Sequential** bir model tanımlıyor olmanızın bir sonucu vardır:
#     her katman, bir önceki katmanın çıktı boyutuna bakarak kendi girdi boyutunu otomatik olarak bilir.
#
# </details>

# %% [markdown]
# ❓ Bu küçük Sinir Ağında kaç parametre bulunmaktadır? ❓

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 5)              │            15 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            24 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │            15 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58 (232.00 B)
#  Trainable params: 58 (232.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# <details>
#     <summary><i>İpucu</i></summary>
#
# ✅ 58 parametreniz olmalıdır.
#
# ❌ Değilse, mimarinizi tekrar kontrol edin.
# </details>

# %% [markdown]
# ### (5) XOR Veri Kümesi

# %% [markdown]
# ❓ <u>XOR Veri Kümesi ile Oynamak</u> ❓
#
# * Oyun Alanında:
# - Veri kümesini “XOR - Özel Veya” olarak değiştirin.
#     - Çok küçük bir **test kaybı** olan iki gizli katmanlı bir model tasarlamaya çalışın.
# - Not: Katman başına nöron sayısını kendiniz seçebilirsiniz.
#
# * Tensorflow/Keras ile kodlama:
# - Playground'da modelinizi oluşturduktan sonra, aşağıda Tensorflow/Keras kütüphanesi ile kodlayın.

# %%
from keras import Sequential, Input, layers

# 1. Modeli başlat
model_xor = Sequential()

# 2. Giriş Katmanı (XOR verisi de X1, X2 koordinatlarından oluşur)
model_xor.add(Input(shape=(2,)))

# 3. Gizli Katmanlar (Playground'daki yapıya göre doldur)
# Örnek: İlk katmanda 8 nöron kullandıysan parantez içine 8 yaz.
model_xor.add(layers.Dense(4, activation='relu'))  # 1. Gizli Katman
model_xor.add(layers.Dense(4, activation='relu'))  # 2. Gizli Katman

# 4. Çıktı Katmanı (Sınıflandırma olduğu için Sigmoid değişmez)
model_xor.add(layers.Dense(1, activation='sigmoid'))

# Modeli özetle (Bakalım kaç parametre çıkacak?)
model_xor.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 4)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 37 (148.00 B)
#  Trainable params: 37 (148.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------------------
# 1. XOR VERİSİNİ OLUŞTURALIM
# -----------------------------------------
# Girişler (Koordinatlar)
X = np.array([[0,0], [0,1], [1,0], [1,1]])
# Çıkışlar (0: Mavi, 1: Turuncu)
y = np.array([[0], [1], [1], [0]])

# -----------------------------------------
# 2. MODELİ DERLE VE EĞİT (PLAY TUŞUNA BASMAK)
# -----------------------------------------
# Modeli eğitime hazırla (Loss fonksiyonu ve Optimizasyon ayarı)
model_xor.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

print("Model eğitiliyor... Lütfen bekleyin ⏳")
# Modeli eğit (Epochs: Playground'daki sayaç)
# XOR zor olduğu için 3000 tur dönmesini istiyoruz.
history = model_xor.fit(X, y, epochs=3000, verbose=0) 
print("Eğitim tamamlandı! ✅")

# -----------------------------------------
# 3. SONUCU GÖRSELLEŞTİR (KARAR SINIRLARI)
# -----------------------------------------
# Grafiğin sınırlarını belirle
x_min, x_max = -0.5, 1.5
y_min, y_max = -0.5, 1.5
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01),
                     np.arange(y_min, y_max, 0.01))

# Tüm noktalar için tahmin yap
Z = model_xor.predict(np.c_[xx.ravel(), yy.ravel()], verbose=0)
Z = Z.reshape(xx.shape)

# Çizim yap
plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, alpha=0.8, cmap=plt.cm.RdBu) # Arka plan renkleri
plt.scatter(X[:, 0], X[:, 1], c=y, s=200, edgecolors='k', cmap=plt.cm.RdBu) # Noktalar
plt.title("XOR Problemi - Modelin Karar Sınırları")
plt.xlabel("X1")
plt.ylabel("X2")
plt.show()
# Out:
# Model eğitiliyor... Lütfen bekleyin ⏳
# Eğitim tamamlandı! ✅

# %% [markdown]
# ### (6) Spiral Veri Seti

# %% [markdown]
# ❓ <u>Spiral Veri Kümesi ile Oynamak</u> ❓
#
# * Oyun Alanında:
# - Veri kümesini “Spiral” olarak değiştirin.
#     - Çok küçük bir **test kaybı** olan üç gizli katmanlı bir model tasarlamaya çalışın.
# - Not: Katman başına nöron sayısını kendiniz seçebilirsiniz.
#
# * Tensorflow/Keras ile kodlama:
# - Playground'da modelinizi oluşturduktan sonra, aşağıda Tensorflow/Keras kütüphanesi ile kodlayın.

# %%
from keras import Sequential, Input, layers

# 1. Modeli başlat
model_spiral = Sequential()

# 2. Giriş Katmanı
model_spiral.add(Input(shape=(2,)))

# 3. Gizli Katmanlar (Playground'daki kazanan sayılarını buraya yaz)
# Örnek: Eğer 8-8-8 yaptıysan hepsine 8 yaz.
model_spiral.add(layers.Dense(8, activation='relu')) # 1. Katman
model_spiral.add(layers.Dense(8, activation='relu')) # 2. Katman
model_spiral.add(layers.Dense(8, activation='relu')) # 3. Katman

# 4. Çıktı Katmanı (Sınıflandırma olduğu için Sigmoid)
model_spiral.add(layers.Dense(1, activation='sigmoid'))

# Özeti gör
model_spiral.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 8)              │            24 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 177 (708.00 B)
#  Trainable params: 177 (708.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### (7) Bir sinir ağı ne kadar derin olmalıdır?

# %% [markdown]
# 👀 Spiral veri setini (Spiral Dataset) uyarlamak için gereken parametre sayısı ile XOR veri setini karşılaştırırsanız, ilkinin çok daha fazla ağırlık (weight) gerektirdiğini görürsünüz....
#
# 😃 Aslında, modelleriniz yeterince derinse, teoride neredeyse her türlü deseni (pattern) öğrenebilirsiniz...
#
# ---
#
# <details>
#   <summary><i>Çok Derin (Very Deep) Sinir Ağları oluşturmalı mıyım?</i></summary>
#
# <u>Örnekler:</u>
#
# * Bir insanı düşünün. Bu kişi Python’da ne kadar çok zaman kod yazarsa, o kadar iyi olur!
# * Bir öğrenciyi düşünün. Bu kişi ne kadar çok çalışırsa, sınavları o kadar iyi geçer. Ancak bazen öğrenciler bir konuya “fazla” odaklanıp dersin genel resmini kaçırabilirler....
#
# <u>Çıkarımlar</u>
#
# 🧠 Derin Öğrenme (Deep Learning) modellerinde, katman sayısı arttıkça verideki örüntüleri öğrenmek için daha fazla fırsat oluşur.
#
# ❗️ Asıl problem **overfitting (aşırı öğrenme)**’den kaçınmaktır ❗️
#
# ☠️ Eğer veriye yeterince gürültü (noise) eklerseniz, modeliniz bu gürültüyü bile “fazla iyi” öğrenmiş olabilir.
#
# 📆 Bir sonraki ders olan **Deep Learning > Optimizers, Loss, & Fitting**, derin öğrenme modellerinde overfitting’i önlemek için hangi teknikleri kullanabileceğimizi anlamanıza yardımcı olacaktır.
#
# </details>
#
# ---
#
# <details>
#   <summary><i>Playground’da overfitting’e ait bir görsel</i></summary>
#
# <img src='https://wagon-public-datasets.s3.amazonaws.com/data-science-images/DL/playground-overfitting.png' width=700 style='margin:auto'>
#
# </details>
#
# ---

# %% [markdown]
# ## Derin Öğrenmede Regresyon

# %% [markdown]
# <u>Derin Öğrenme kullanarak Regresyon Görevini tamamlamaya çalışalım</u>
#
#
# Bu sefer, son katman artık şöyle görünmeyecek:
# ```python
# model.add(layers.Dense(1, activation=‘sigmoid’))
# ```
#
# bunun yerine  :
# ```python
# model.add(layers.Dense(1, activation=‘linear’))
# ```
#
# Bu, bu ağın çıktısının artık $0$ ile $1$ (olasılık) arasında değil, $ -\infty$ ile $+ \infty$ arasında olduğu anlamına gelir.

# %% [markdown]
# ❓ <u>Regresyon Veri Kümesi ile Oynamak</u> ❓
#
# * Playground'da:
# - Veri kümesini “Regresyon” olarak değiştirin.
#     - **Test kaybı** çok düşük olan bir model tasarlamaya çalışın.
#         - Not: Katman sayısını ve katman başına nöron sayısını kendiniz seçebilirsiniz.
#
# * Tensorflow/Keras ile kodlama:
#     - Playground'da modelinizi oluşturduktan sonra, aşağıda Tensorflow/Keras kütüphanesi ile kodlayın.

# %%
# Regresyon Veri Setine iyi uyarlanabilen Sinir Ağı
from keras import Sequential, Input, layers

# 1. Modeli başlat
model_reg = Sequential()

# 2. Giriş Katmanı
model_reg.add(Input(shape=(2,)))

# 3. Gizli Katmanlar (Burada özgürsün, örneğin 2 katman koyabilirsin)
model_reg.add(layers.Dense(5, activation='relu'))
model_reg.add(layers.Dense(3, activation='relu'))

# 4. ÇIKTI KATMANI (DİKKAT! Burası değişti) ⚠️
# Regresyon olduğu için 'sigmoid' YERİNE 'linear' kullanıyoruz.
# Çünkü çıktının -sonsuz ile +sonsuz arasında herhangi bir sayı olmasını istiyoruz.
model_reg.add(layers.Dense(1, activation='linear'))

# Özeti gör
model_reg.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_11 (Dense)                │ (None, 5)              │            15 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 3)              │            18 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 37 (148.00 B)
#  Trainable params: 37 (148.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 🏁 Artık Tensorflow'un Keras ile aynı şeyleri doğrudan yapmaya hazırsınız!
#
# 💪 Bu, Sinir Ağları / Derin Öğrenme Modelleri hakkında bir Isınma egzersiziydi... (gerçi, bu zorlukta ağlarımız o kadar da “derin” değildi).
#
#
# 💾 Not defterinizi `git add/commit/push` yapmayı unutmayın...
#
# 🚀 ... ve bir sonraki göreve geçin!
